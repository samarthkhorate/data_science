# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("scholarship.csv")

# %%
data.head()
# Out:
#    semester_percentage  scholarship_exam_marks  got_scholarship
# 0                 71.9                      26                1
# 1                 74.6                      38                1
# 2                 75.4                      40                1
# 3                 64.2                       8                1
# 4                 72.3                      17                0

# %%
sns.distplot(data["scholarship_exam_marks"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\828206924.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# <Axes: xlabel='scholarship_exam_marks', ylabel='Density'>

# %%
data["scholarship_exam_marks"].skew()
# Out:
# 0.8356419499466834

# %%
data["scholarship_exam_marks"].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: scholarship_exam_marks, dtype: float64

# %%
sns.boxplot(data["scholarship_exam_marks"])
# Out:
# <Axes: ylabel='scholarship_exam_marks'>

# %%
percentile25 = data["scholarship_exam_marks"].quantile(0.25)
percentile75 = data["scholarship_exam_marks"].quantile(0.75)

# %%
IQR = percentile75 - percentile25

# %%
min = percentile25 - 1.5*IQR
max = percentile75 + 1.5*IQR

# %%
#trimming
new_data = data[(data["scholarship_exam_marks"]>min) & (data["scholarship_exam_marks"]<max)]

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(data["scholarship_exam_marks"])

plt.subplot(2,2,2)
sns.boxplot(data["scholarship_exam_marks"])

plt.subplot(2,2,3)
sns.distplot(data_new["scholarship_exam_marks"])

plt.subplot(2,2,4)
sns.boxplot(data_new["scholarship_exam_marks"])

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3164\3437727703.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       6 sns.boxplot(data["scholarship_exam_marks"])
#       8 plt.subplot(2,2,3)
# ----> 9 sns.distplot(data_new["scholarship_exam_marks"])
#      11 plt.subplot(2,2,4)
#      12 sns.boxplot(data_new["scholarship_exam_marks"])
#
# NameError: name 'data_new' is not defined

# %%
#capping
new_data2 = data.copy()
new_data2["scholarship_exam_marks"] = np.where(data["scholarship_exam_marks"]>max,
         max, 
         np.where(data["scholarship_exam_marks"]<min,min, data["scholarship_exam_marks"]))

# %%
new_data2.shape
# Out:
# (1000, 3)

# %%
new_data2["scholarship_exam_marks"].describe()
# Out:
# count    1000.000000
# mean       32.136500
# std        18.865419
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max        84.500000
# Name: scholarship_exam_marks, dtype: float64

# %%
sns.boxplot(data["scholarship_exam_marks"])
# Out:
# <Axes: ylabel='scholarship_exam_marks'>
